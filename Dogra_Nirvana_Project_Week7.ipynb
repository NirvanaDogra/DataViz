# %% [markdown]
# <a href="https://colab.research.google.com/github/NirvanaDogra/DataViz/blob/main/Dogra_Nirvana_Project_Week7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Generate some random data
x = np.random.randn(1000)
y = np.random.randn(1000)

# Create a DataFrame with the data
data = pd.DataFrame({'x': x, 'y': y})

# Plot the data as a scatter plot
sns.scatterplot(x='x', y='y', data=data)

# Add a title and axis labels
plt.title('Random Scatter Plot')
plt.xlabel('X')
plt.ylabel('Y')

# Show the plot
plt.show()

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Generate some random data
x = np.random.randn(1000)
y = np.random.randn(1000)

# Create a DataFrame with the data
data = pd.DataFrame({'x': x, 'y': y})

# Plot the data as a hexbin plot
sns.jointplot(x='x', y='y', data=data, kind='kde', cmap='Blues', height=8)

# Add a title and axis labels
plt.subplots_adjust(top=0.9)
plt.suptitle('Random Hexbin Plot', fontsize=16)
plt.xlabel('X', fontsize=12)
plt.ylabel('Y', fontsize=12)

# Show the plot
plt.show()

# %%
import seaborn as sns

# Load iris dataset
iris = sns.load_dataset('iris')

# Create scatterplot matrix
sns.pairplot(iris, diag_kind='hist')

# Show plot
plt.show()
